# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
import os

DATA = "./data/data.csv"
df = pd.read_csv(DATA)
df = df.sort_values(['nodes', 'interval'])
print(df)

netsizes = list(df["nodes"].unique())
intervals = list(df["interval"].unique())
#repeats = df["Run Index"].unique()
repeats = [1]
number_of_colors = max(len(netsizes), len(intervals))

colors = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)]) for i in range(number_of_colors)]

# plot Stale Block Rate
fig, ax = plt.subplots()
fig.suptitle("Stale Block Rate")
for size in netsizes:
    color = colors[netsizes.index(size)]
    for run in repeats:
        subset = df[df['nodes'] == size]
        subset.plot(x="interval", y="SBR", ax=ax, label=str(size), color=color)
ax.set(xlabel="Block Interval (s)", ylabel="Stale Block Rate")

# plot throughput as a function of network size
fig, ax = plt.subplots()
fig.suptitle("Throughput")
for interval in intervals:
    color = colors[intervals.index(interval)]
    for run in repeats:
        subset = df[df['interval'] == interval]
        subset = subset[subset['nodes'] <= 64]
        subset.plot(x="nodes", y="throughput", ax=ax, label=str(interval), color=color)
ax.set(xlabel="Network Size", ylabel="Throughput (bytes/sec)")

'''
# plot Throughput as a function of block interval
fig, ax = plt.subplots()
fig.suptitle("Throughput")
for size in netsizes:
    color = colors[netsizes.index(size)]
    for run in repeats:
        subset = df[df['nodes'] == size]
        subset = subset[subset['interval'] <= 200]
        subset.plot(x="interval", y="throughput", ax=ax, label=str(size), color=color)
ax.set(xlabel="Block Interval (s)", ylabel="Throughput (bytes/sec)")
'''
#fig = ax.get_figure()
#fig.savefig("/Users/amiecorso/Desktop/exp1-" + str(netsize) + ".pdf")

plt.show()
# Out:
#      nodes  interval  blocksize   SBR  throughput
# 27       1         5     535000  0.00   131127.45
# 187      1         5     535000  0.00   131127.45
# 154      1        10     535000  0.00    61867.59
# 155      1        10     535000  0.00    61867.59
# 127      1        20     535000  0.00    30073.07
# 162      1        20     535000  0.00    30073.07
# 119      1        30     535000  0.00    19894.02
# 46       1        40     535000  0.00    14836.38
# 33       1        50     535000  0.00    11838.25
# 64       1        50     535000  0.00    11838.25
# 45       1        80     535000  0.00     7368.89
# 12       1       100     535000  0.00     5886.40
# 114      1       100     535000  0.00     5886.40
# 17       1       200     535000  0.00     2935.49
# 176      1       200     535000  0.00     2935.49
# 57       1       400     535000  0.00     1465.78
# 131      1       400     535000  0.00     1465.78
# 124      1       600     535000  0.00      976.85
# 83       1       800     535000  0.00      732.45
# 137      1       800     535000  0.00      732.45
# 24       1      1000     535000  0.00      585.89
# 36       1      1000     535000  0.00      585.89
# 25       1      2000     535000  0.00      292.87
# 100      1      3000     535000  0.00      195.23
# 30       1      4000     535000  0.00      146.42
# 2        2         5     535000  0.01    74383.04
# 63       2         5     535000  0.01    74383.04
# 111      2        10     535000  0.04    35489.22
# 158      2        10     535000  0.04    35489.22
# 79       2        20     535000  0.09    17435.68
# ..     ...       ...        ...   ...         ...
# 21      64      1000     535000  0.67      176.26
# 166     64      1000     535000  0.66      175.51
# 148     64      2000     535000  0.53      127.57
# 159     64      3000     535000  0.44      101.80
# 9       64      4000     535000  0.38       86.77
# 68     128         5     535000  0.95      710.05
# 140    128         5     535000  0.94      833.89
# 37     128        10     535000  0.98      407.09
# 59     128        10     535000  0.98      383.88
# 122    128        20     535000  0.99      193.99
# 198    128        20     535000  0.99      193.79
# 152    128        30     535000  1.00      162.12
# 147    128        40     535000  1.00      147.48
# 179    128        50     535000  0.99      155.24
# 182    128        50     535000  1.00      144.68
# 16     128        80     535000  0.98      163.33
# 41     128       100     535000  0.97      164.95
# 71     128       100     535000  0.97      164.47
# 51     128       200     535000  0.93      190.48
# 195    128       200     535000  0.93      191.52
# 102    128       400     535000  0.85      195.66
# 120    128       400     535000  0.85      196.58
# 196    128       600     535000  0.78      187.30
# 106    128       800     535000  0.75      176.71
# 189    128       800     535000  0.74      176.09
# 80     128      1000     535000  0.70      162.35
# 178    128      1000     535000  0.70      166.62
# 35     128      2000     535000  0.54      124.17
# 65     128      3000     535000  0.44      103.04
# 18     128      4000     535000  0.39       81.40
#
# [200 rows x 5 columns]
